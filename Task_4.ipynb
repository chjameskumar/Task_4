# %% [markdown]
# <a href="https://colab.research.google.com/github/chjameskumar/Task_4/blob/main/Task_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
college_1 = pd.read_csv('college_1.csv')
college_2 = pd.read_csv('college_2.csv')

# %%
college_1
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
college_2
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %%
college = pd.merge(college_1, college_2, how='outer')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py:1208: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation
#   UserWarning,

# %%
college
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        NaN
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
Exceeded_expectations = college[college['CodeKata Score'] > 15000]
Reached_expectations = college[(college['CodeKata Score'] <= 15000) & (college['CodeKata Score'] > 10000)]
Needs_Improvement = college[(college['CodeKata Score'] <= 10000) & (college['CodeKata Score'] > 7000)]
Unsatisfactory = college[college['CodeKata Score'] <= 7000]

# %%
Exceeded_expectations.to_csv('Exceeded_expectations.csv', index = False)
Reached_expectations.to_csv('Reached_expectations.csv', index = False)
Needs_Improvement.to_csv('Needs_Improvement.csv', index = False)
Unsatisfactory.to_csv('Unsatisfactory.csv', index = False)

# %%
Exceeded_expectations = pd.read_csv('Exceeded_expectations.csv')
Reached_expectations = pd.read_csv('Reached_expectations.csv')
Needs_Improvement = pd.read_csv('Needs_Improvement.csv')
Unsatisfactory = pd.read_csv('Unsatisfactory.csv')

# %%
Exceeded_expectations
# Out:
#             Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0      A.Dharani    82.0   20.0              24500           24500
# 1    V.JEEVITHA     82.0   20.0              21740           21740
# 2    HEMAVATHI.R   100.0  100.0              19680           19680
# 3  ASHOK KUMAR K   100.0   31.0              19400           19400
#
#                                Department  Rising  python_en  \
# 0        Computer Science and Engineering       0        NaN
# 1        Computer Science and Engineering       0        NaN
# 2        Computer Science and Engineering       0        NaN
# 3  Electronics and Electrical Engineering       0        0.0
#
#    computational_thinking
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     9.0

# %%
Reached_expectations
# Out:
#                 Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        Mugunthan S   100.0   47.0              10610           10610
# 1            Chandru     0.0    0.0              14150           14490
# 2  Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 3    Bodipudi Harini    -1.0   35.0              10040           10040
#
#                                   Department  Rising  python_en  \
# 0           Computer Science and Engineering       0        NaN
# 1           Computer Science and Engineering     340       20.0
# 2           Computer Science and Engineering    2000       55.0
# 3  Electronics and Communication Engineering       0        0.0
#
#    computational_thinking
# 0                     NaN
# 1                     0.0
# 2                     6.0
# 3                    -1.0

# %%
Needs_Improvement
# Out:
#                       Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0              Sathammai.S   100.0    8.0               8980            8980
# 1             NIVEESHWAR S   100.0    0.0               8200            8200
# 2            KALAIARASAN K    85.0   47.0               7750            7880
# 3     MOHAMED ZUBAIR AHMED    82.0    4.0               7020            7020
# 4                VIINU V P    -1.0   24.0               9150            9150
# 5               Poojitha Y     0.0   35.0               7210            8970
# 6   Gowtham Chandrasekaran    -1.0    0.0               7250            8950
# 7                Gowtham R    -1.0    4.0               8650            8650
# 8                 shifak N    58.0    0.0               5180            8320
# 9                  Balaji     -1.0   20.0               6170            8160
# 10                Rushitha    -1.0   62.0               7470            8090
# ...

# %%
Unsatisfactory
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        J.SUGANTHI    27.0  50.00               5860            5860
# 1      thamizhpaana    29.0   0.00               5500            5500
# 2   Iyappan Samiraj    50.0  24.00               5400            5400
# 3      Ponniyamma.R   100.0  11.25               5380            5380
# 4         SABAPATHI   100.0   0.00               5280            5280
# ..              ...     ...    ...                ...             ...
# 88    praveen raj j    24.0   0.00               2380            2380
# 89       AMARNATH D    -1.0  12.00               1890            1890
# 90             bala    32.0   0.00               1720            1720
# 91             XY Z    -1.0  -1.00                  0               0
# 92        Hariharan    -1.0  -1.00                  0               0
#
#                                    Department  Rising  python_en  \
# ...

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
print('Average of previous week geekions (Previous Geekions) :', college['Previous Geekions'].mean())
print('Average of this week geekions (CodeKata Score) :', college['CodeKata Score'].mean())
# Out:
# Average of previous week geekions (Previous Geekions) : 3842.3529411764707
# Average of this week geekions (CodeKata Score) : 4051.764705882353

# %% [markdown]
# ###### No of students participated

# %%
print('No.of students participated :', college['Name'].count())
# Out:
# No.of students participated : 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
college.nlargest(3, columns = ['Rising'])
# Out:
#                   Name  python  mysql  Previous Geekions  CodeKata Score  \
# 92            shifak N    58.0    0.0               5180            8320
# 86   Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 102     Narasimhan Y L    -1.0    0.0               4800            6800
#
#                                  Department  Rising  python_en  \
# 92   Electronics and Electrical Engineering    3140        0.0
# 86         Computer Science and Engineering    2000       55.0
# 102        Computer Science and Engineering    2000       -1.0
#
#      computational_thinking
# 92                      0.0
# 86                      6.0
# 102                     0.0

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
for i in range(120):
  college['Shining'] = college['Previous Geekions'] + college['CodeKata Score']

# %%
college.nlargest(3, columns = ['Shining'])
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  \
# 0  Computer Science and Engineering       0        NaN
# 1  Computer Science and Engineering       0        NaN
# 2  Computer Science and Engineering       0        NaN
#
#    computational_thinking  Shining
# 0                     NaN    49000
# 1                     NaN    43480
# 2                     NaN    39360

# %%
college.drop('Shining', axis = 1, inplace = True)

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
cse = college[college['Department'] == 'Computer Science and Engineering']
ece = college[college['Department'] == 'Electronics and Communication Engineering']
eee = college[college['Department'] == 'Electronics and Electrical Engineering']

# %%
import matplotlib.pyplot as plt
labels = college['Department'].unique()
x = [cse['CodeKata Score'].mean(), ece['CodeKata Score'].mean(), eee['CodeKata Score'].mean()]

# %%
plt.pie(x, labels = labels, shadow = True, radius = 2)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fb0b41a2d50>,
# ...
#  [Text(0.26981639239299027, 2.1833916539173712, 'Computer Science and Engineering'),
#   Text(-1.8803296099195828, -1.1420860554527712, 'Electronics and Communication Engineering'),
#   Text(1.3640749606314602, -1.7260647443761434, 'Electronics and Electrical Engineering')])

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)
